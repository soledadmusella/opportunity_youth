# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv('kingcounty.csv')

# %%
df
# Out:
#            tabblk2010  st stusps  \
# 0     530330311004021  53     WA
# 1     530330311004020  53     WA
# 2     530330306002025  53     WA
# 3     530330305012016  53     WA
# 4     530330305012019  53     WA
# ...               ...  ..    ...
# 8910  530330268012005  53     WA
# 8911  530330268012002  53     WA
# 8912  530330268012001  53     WA
# 8913  530330270003001  53     WA
# 8914  530330265002002  53     WA
#
#                                                  stname    cty  \
# 0     Washington                                    ...  53033
# 1     Washington                                    ...  53033
# 2     Washington                                    ...  53033
# 3     Washington                                    ...  53033
# 4     Washington                                    ...  53033
# ...                                                 ...    ...
# 8910  Washington                                    ...  53033
# ...

# %%
df.shape
# Out:
# (8915, 43)

# %%
import geopandas

# %%
# !pwd
# Out:
# /Users/aqureshi/Desktop/DS_021720/opportunity_youth/notebooks

# %%
southkingcounty = geopandas.read_file("../data/raw/tl_2017_53_puma10.shp")

# %%
southkingcounty.plot()

# %%
southkingcounty.plot(column=faas)
# Out:
#    STATEFP10 PUMACE10  GEOID10  \
# 0         53    10200  5310200
# 1         53    10100  5310100
# 2         53    10400  5310400
# 3         53    10504  5310504
# 4         53    10503  5310503
# 5         53    10600  5310600
# 6         53    10703  5310703
# 7         53    11000  5311000
# 8         53    11502  5311502
# 9         53    11612  5311612
# 10        53    11701  5311701
# 11        53    11702  5311702
# 12        53    11703  5311703
# 13        53    11705  5311705
# 14        53    11103  5311103
# 15        53    11101  5311101
# 16        53    11104  5311104
# 17        53    11200  5311200
# 18        53    11300  5311300
# 19        53    11900  5311900
# 20        53    10300  5310300
# 21        53    10502  5310502
# 22        53    10701  5310701
# 23        53    10702  5310702
# 24        53    10902  5310902
# 25        53    11102  5311102
# 26        53    11801  5311801
# 27        53    11706  5311706
# 28        53    10800  5310800
# ...

# %%
import pandas as pd
df = pd.read_csv('zipcode.csv')
df.head()
# Out:
#    st   zcta
# 0  53  98146
# 1  53  98146
# 2  53  98166
# 3  53  98108
# 4  53  98042

# %%
import geopandas
shape_file = geopandas.read_file("/Users/aqureshi/Desktop/DS_021720/opportunity_youth/data/raw/tl_2017_53_tract")

# %%
shape_file
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  \
# 0         53      011  041107  53011041107  411.07  Census Tract 411.07
# 1         53      061  042006  53061042006  420.06  Census Tract 420.06
# 2         53      061  050102  53061050102  501.02  Census Tract 501.02
# 3         53      053  073122  53053073122  731.22  Census Tract 731.22
# 4         53      061  050600  53061050600     506     Census Tract 506
# ...      ...      ...     ...          ...     ...                  ...
# 1453      53      035  092000  53035092000     920     Census Tract 920
# 1454      53      035  090101  53035090101  901.01  Census Tract 901.01
# 1455      53      035  080200  53035080200     802     Census Tract 802
# 1456      53      035  091100  53035091100     911     Census Tract 911
# 1457      53      031  990000  53031990000    9900    Census Tract 9900
#
#       MTFCC FUNCSTAT      ALAND     AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
shape_file.plot()

# %%
shape_file
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  \
# 0         53      011  041107  53011041107  411.07  Census Tract 411.07
# 1         53      061  042006  53061042006  420.06  Census Tract 420.06
# 2         53      061  050102  53061050102  501.02  Census Tract 501.02
# 3         53      053  073122  53053073122  731.22  Census Tract 731.22
# 4         53      061  050600  53061050600     506     Census Tract 506
# ...      ...      ...     ...          ...     ...                  ...
# 1453      53      035  092000  53035092000     920     Census Tract 920
# 1454      53      035  090101  53035090101  901.01  Census Tract 901.01
# 1455      53      035  080200  53035080200     802     Census Tract 802
# 1456      53      035  091100  53035091100     911     Census Tract 911
# 1457      53      031  990000  53031990000    9900    Census Tract 9900
#
#       MTFCC FUNCSTAT      ALAND     AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
df2 = pd.read_csv('southking.csv')
df2
# Out:
#       st                                            ctyname         trct  \
# 0     53  King County, WA                               ...  53033026700
# 1     53  King County, WA                               ...  53033027600
# 2     53  King County, WA                               ...  53033027600
# 3     53  King County, WA                               ...  53033026300
# 4     53  King County, WA                               ...  53033029307
# ...   ..                                                ...          ...
# 9301  53  King County, WA                               ...  53033031703
# 9302  53  King County, WA                               ...  53033031703
# 9303  53  Pierce County, WA                             ...  53053070100
# 9304  53  Pierce County, WA                             ...  53053070100
# 9305  53  Pierce County, WA                             ...  53053070100
#
#                                                trctname   blklatdd  \
# ...

# %%
df['zcta'].unique()
# Out:
# array([98146, 98166, 98108, 98042, 98058, 98030, 98003, 98002, 98092,
#        98056, 98022, 98070, 98059, 98057, 98188, 98148, 98038, 98198,
#        98055])
