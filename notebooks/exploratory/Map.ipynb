# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import geopandas as gpd
# %matplotlib inline

# %%
wa_puma = gpd.read_file('/Users/aqureshi/Desktop/DS_021720/opportunity_youth/data/raw/tl_2017_53_puma10.shp')
wa_puma
# Out:
#    STATEFP10 PUMACE10  GEOID10  \
# 0         53    10200  5310200
# 1         53    10100  5310100
# 2         53    10400  5310400
# 3         53    10504  5310504
# 4         53    10503  5310503
# 5         53    10600  5310600
# 6         53    10703  5310703
# 7         53    11000  5311000
# 8         53    11502  5311502
# 9         53    11612  5311612
# 10        53    11701  5311701
# 11        53    11702  5311702
# 12        53    11703  5311703
# 13        53    11705  5311705
# 14        53    11103  5311103
# 15        53    11101  5311101
# 16        53    11104  5311104
# 17        53    11200  5311200
# 18        53    11300  5311300
# 19        53    11900  5311900
# 20        53    10300  5310300
# 21        53    10502  5310502
# 22        53    10701  5310701
# 23        53    10702  5310702
# 24        53    10902  5310902
# 25        53    11102  5311102
# 26        53    11801  5311801
# 27        53    11706  5311706
# 28        53    10800  5310800
# ...

# %%
wa_puma.loc[:,'PUMACE10'] = wa_puma['PUMACE10'].astype(int)
wa_puma.loc[:, 'GEOID10'] = wa_puma['GEOID10'].astype(int)
wa_puma.head()
# Out:
#   STATEFP10  PUMACE10  GEOID10  \
# 0        53     10200  5310200
# 1        53     10100  5310100
# 2        53     10400  5310400
# 3        53     10504  5310504
# 4        53     10503  5310503
#
#                                           NAMELSAD10 MTFCC10 FUNCSTAT10  \
# 0            Skagit, Island & San Juan Counties PUMA   G6120          S
# 1               Whatcom County--Bellingham City PUMA   G6120          S
# 2  Stevens, Okanogan, Pend Oreille & Ferry Counti...   G6120          S
# 3           Spokane County (Outer)--Cheney City PUMA   G6120          S
# 4  Spokane County (East Central)--Greater Spokane...   G6120          S
#
#        ALAND10    AWATER10   INTPTLAT10    INTPTLON10  \
# 0   5470622131  2441658886  +48.4470835  -122.1737477
# 1   5459332804  1028183246  +48.8426531  -121.8364325
# 2  29389124389   489162432  +48.5031090  -118.7866777
# 3   3983412021    35812133  +47.5972847  -117.1210417
# 4    270926976     5004332  +47.6561281  -117.1818649
#
# ...

# %%
wa_puma.plot()
plt.show()

# %%
# !pip install lxml

# %%
data = pd.read_csv('/Users/aqureshi/Desktop/DS_021720/opportunity_youth/data/raw/df_zip.csv', header=2)

# %%
df_zips = data.copy()
df_zips
# Out:
#        1  Zip Code         City       County Zip Code Map
# 0      2     98001       Auburn         King     View Map
# 1      3     98002       Auburn         King     View Map
# 2      4     98003  Federal Way         King     View Map
# 3      5     98004     Bellevue         King     View Map
# 4      6     98005     Bellevue         King     View Map
# ..   ...       ...          ...          ...          ...
# 727  729     99363      Wallula  Walla Walla     View Map
# 728  730     99371    Washtucna        Adams     View Map
# 729  731     99401      Anatone       Asotin     View Map
# 730  732     99402       Asotin       Asotin     View Map
# 731  733     99403    Clarkston       Asotin     View Map
#
# [732 rows x 5 columns]

# %%
df_zips = df_zips[df_zips.City.isin(['Auburn', 'Burien', 'Covington', 
                                   'Des Moines', 'Enumclaw', 'Federal Way', 'Kent', 'Maple Valley', 
                                   'Normandy Park', 'Renton', 'Tukwila', 'SeaTac', 'White Center', 'Vashion'])].reset_index(drop=True)
df_zips
# Out:
#      1  Zip Code          City County Zip Code Map
# 0    2     98001        Auburn   King     View Map
# 1    3     98002        Auburn   King     View Map
# 2    4     98003   Federal Way   King     View Map
# 3   20     98022      Enumclaw   King     View Map
# 4   21     98023   Federal Way   King     View Map
# 5   28     98030          Kent   King     View Map
# 6   29     98031          Kent   King     View Map
# 7   30     98032          Kent   King     View Map
# 8   33     98035          Kent   King     View Map
# 9   36     98038  Maple Valley   King     View Map
# 10  40     98042          Kent   King     View Map
# 11  50     98055        Renton   King     View Map
# 12  51     98056        Renton   King     View Map
# 13  52     98057        Renton   King     View Map
# 14  53     98058        Renton   King     View Map
# 15  54     98059        Renton   King     View Map
# 16  57     98063   Federal Way   King     View Map
# ...

# %%
zcta_trct = pd.read_csv('/Users/aqureshi/Desktop/DS_021720/opportunity_youth/data/processed/zcta_trct.csv')

# %%
zcta_trct.head()
# Out:
#     zcta         trct
# 0  99217  53063011202
# 1  99208  53063010503
# 2  99156  53063010100
# 3  99009  53063010100
# 4  99009  53063010100

# %%
wa_puma.head()
# Out:
#   STATEFP10  PUMACE10  GEOID10  \
# 0        53     10200  5310200
# 1        53     10100  5310100
# 2        53     10400  5310400
# 3        53     10504  5310504
# 4        53     10503  5310503
#
#                                           NAMELSAD10 MTFCC10 FUNCSTAT10  \
# 0            Skagit, Island & San Juan Counties PUMA   G6120          S
# 1               Whatcom County--Bellingham City PUMA   G6120          S
# 2  Stevens, Okanogan, Pend Oreille & Ferry Counti...   G6120          S
# 3           Spokane County (Outer)--Cheney City PUMA   G6120          S
# 4  Spokane County (East Central)--Greater Spokane...   G6120          S
#
#        ALAND10    AWATER10   INTPTLAT10    INTPTLON10  \
# 0   5470622131  2441658886  +48.4470835  -122.1737477
# 1   5459332804  1028183246  +48.8426531  -121.8364325
# 2  29389124389   489162432  +48.5031090  -118.7866777
# 3   3983412021    35812133  +47.5972847  -117.1210417
# 4    270926976     5004332  +47.6561281  -117.1818649
#
# ...

# %%
kc_puma = wa_puma.loc[(wa_puma.PUMACE10 >= 11611 ) & (wa_puma.PUMACE10 <= 11615)]
kc_puma
# I have looked at the website and also at the data to double check whether some of these are within south king county
# Since some of them are not, I have narrowed it down to 11611-11615.
# Out:
#    STATEFP10  PUMACE10  GEOID10  \
# 9         53     11612  5311612
# 35        53     11611  5311611
# 41        53     11615  5311615
# 42        53     11614  5311614
# 44        53     11613  5311613
#
#                                            NAMELSAD10 MTFCC10 FUNCSTAT10  \
# 9   King County (Far Southwest)--Federal Way, Des ...   G6120          S
# 35  King County (West Central)--Burien, SeaTac, Tu...   G6120          S
# 41  King County (Southeast)--Maple Valley, Covingt...   G6120          S
# 42  King County (Southwest)--Auburn City & Lakelan...   G6120          S
# 44    King County (Southwest Central)--Kent City PUMA   G6120          S
#
#        ALAND10   AWATER10   INTPTLAT10    INTPTLON10  \
# 9    160638807  279665546  +47.4764651  -122.4271168
# 35   104685305    6835973  +47.4500687  -122.3101564
# 41  1704963276   21281417  +47.2986756  -121.7866429
# 42   177945706    2750138  +47.2844346  -122.1690701
# 44    96646675    1914377  +47.3879703  -122.2127275
#
# ...

# %%
base = wa_puma.plot(color ='grey', zorder=1)
ax = kc_puma.plot(color ='pink', edgecolor='white', zorder=2)

kc_puma.plot()
plt.show()
#Here we can see a vague outline of south king county. I will attempt to make this more defined
